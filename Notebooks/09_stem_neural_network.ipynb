# %% [markdown]
# # STEM Neural Network Model
#
# This notebook builds a STEM-specific neural network model to predict student success using the OULAD dataset. The model focuses only on students enrolled in STEM modules and evaluates whether a deep learning approach can match or outperform the STEM XGBoost model.

# %%
# Import libraries

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_auc_score, classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
stem_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 stem_df.head()
#
# NameError: name 'stem_df' is not defined
